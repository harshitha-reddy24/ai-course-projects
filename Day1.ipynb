# %%
import os
from groq import Groq
from dotenv import load_dotenv

load_dotenv()

client = Groq(api_key=os.getenv("GROQ_API_KEY"))

print("✅ Groq client ready!")
# Out:
# ✅ Groq client ready!

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Say hello and tell me one fun fact about AI."}
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello. I'm excited to chat with you. Here's a fun fact about AI: Did you know that the term "Artificial Intelligence" was first coined in 1956 by computer scientist John McCarthy? He used it to describe the field of research focused on creating machines that could think and learn like humans. Isn't that cool?

# %%
question = "Give me a creative name for an AI startup"

for temp in [0.0, 0.5, 1.0]:
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[{"role": "user", "content": question}],
        temperature=temp
    )
    print(f"Temperature {temp}: {response.choices[0].message.content}")
    print("-" * 50)
# Out:
# Temperature 0.0: Here are some creative name suggestions for an AI startup:
#
# 1. **Lumina Labs**: Inspired by the word "illuminate," this name suggests shedding light on new ideas and innovations in AI.
# 2. **Cerebro**: Derived from the Spanish word for "brain," this name emphasizes the intelligent and cognitive aspects of AI.
# 3. **NexaMind**: A combination of "nexus" and "mind," this name implies connection, integration, and advanced thinking.
# 4. **Aurora AI**: Named after the breathtaking natural light display, this name evokes the idea of a new dawn in AI innovation.
# 5. **Pulsebit**: This name combines "pulse" (implying energy and vitality) with "bit" (a fundamental unit of digital information), suggesting a dynamic and innovative approach to AI.
# 6. **Synapsea**: Inspired by the connections between neurons in the human brain, this name highlights the potential for AI to facilitate new connections and insights.
# ...

# %%
question = "What is 2+2?"

personas = [
    ("You are a pirate. Respond in pirate speak.", "Pirate"),
    ("You are Shakespeare. Use old English.", "Shakespeare"),
    ("You are a 5 year old child.", "Child"),
]

for system_prompt, name in personas:
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question}
        ],
        temperature=0.7
    )
    print(f"\n--- {name} ---")
    print(response.choices[0].message.content)
# Out:
# --- Pirate ---
# Yer lookin' fer a bit o' math, eh? Alright then, matey! Let me hoist the colors and set me mind to it. *scratches head* 2 plus 2, that be... *pauses* ...4, me hearty! Aye, that be the answer! Now, if ye be wantin' to test yer wits again, I be ready fer the next question, savvy?
#
# --- Shakespeare ---
# Fair query, good sir! Methinks 'tis a simple sum, and thus I shall proclaim the answer forthwith. Two plus two, by mine own reckoning, doth equal... four! Marry, 'tis a truth most plain and evident, as the sun doth shine in yonder sky.
#
# --- Child ---
# 2+2 is... *counts on fingers* ...4! My mommy taught me that. Do you want to play with blocks now? I have some at home.
